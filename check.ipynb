# %%
import requests
r = requests.get("http://localhost:8000/health")
print(r.json())
# Out:
# {'status': 'ok', 'models': {'diabetes': 'loaded', 'heart': 'loaded'}, 'thresholds': {'diabetes': 0.24, 'heart': 0.59}}

# %%
import os
print(os.getcwd())          # current folder
print(os.listdir('.'))      # saari files dekho
# Out:
# C:\Users\SAEEDCOMPUTERS\5th sem project
# ...
